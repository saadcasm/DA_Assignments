# %% [markdown]
# ![image.png](attachment:b5d8b9da-06d3-4552-914b-b578e06a1317.png)

# %%
class ElectricVehicle:
    def charge(self):
        print("Charging the electric vehicle.")

class GasolineVehicle:
    def fuel_up(self):
        print("Charging the electric vehicle.")

class HybridCar(ElectricVehicle, GasolineVehicle):
    def drive(self):
        print("Driving the hybrid car.")

car = HybridCar()
car.charge()
car.fuel_up()
car.drive()
# Out:
# Charging the electric vehicle.
# Charging the electric vehicle.
# Driving the hybrid car.

# %% [markdown]
# ![image.png](attachment:62e07939-c363-4ceb-af9e-06416cb88369.png)

# %%
class Animal:
    def make_sound(self):
        print("Animal makes a sound.")

class Lion(Animal):
    def make_sound(self):
        print("Roar")

class Cat(Animal):
    def make_sound(self):
        print("Meow")

lion = Lion()
cat = Cat()

lion.make_sound()
cat.make_sound()
# Out:
# Roar
# Meow

# %% [markdown]
# ![image.png](attachment:e3577ae4-6a23-47ca-9e87-1b473343a872.png)

# %%
from abc import ABC, abstractmethod

class SmartHomeDevice(ABC):
    @abstractmethod
    def turn_on(self):
        pass

    @abstractmethod
    def turn_off(self):
        pass

class Light(SmartHomeDevice):
    def turn_on(self):
        print("• Turning on the light...")
        print("• Light is ON")

    def turn_off(self):
        print("• Turning off the light...")
        print("• Light is OFF")

light = Light()
light.turn_on()
light.turn_off()
# Out:
# • Turning on the light...
# • Light is ON
# • Turning off the light...
# • Light is OFF

# %% [markdown]
# ![image.png](attachment:40452081-d889-47a1-b969-be63e5c2aec5.png)

# %%
class Greeting:
    def greet(self, *args):
        if len(args) == 0:
            print("Hello!")
        elif len(args) == 1:
            print(f"Hello, {args[0]}!")
        elif len(args) == 2:
            print(f"{args[1]}, {args[0]}!")
        else:
            print("Too many arguments!")

greeting = Greeting()
greeting.greet()
greeting.greet("John")
greeting.greet("John", "Good morning")
# Out:
# Hello!
# Hello, John!
# Good morning, John!

# %% [markdown]
# ![image.png](attachment:c3224661-a30a-45c8-ba5d-0298d036d682.png)

# %%
class CarRental:
    def __init__(self, car_name, price_per_day, rental_days):
        self.__car_name = car_name
        self.__price_per_day = price_per_day
        self.__rental_days = rental_days

    def get_car_name(self):
        return self.__car_name

    def set_car_name(self, car_name):
        self.__car_name = car_name

    def get_price_per_day(self):
        return self.__price_per_day

    def set_price_per_day(self, price_per_day):
        self.__price_per_day = price_per_day

    def get_rental_days(self):
        return self.__rental_days

    def set_rental_days(self, rental_days):
        if rental_days < 0:
            self.__rental_days = 0
        else:
            self.__rental_days = rental_days

    def calculate_total_cost(self):
        return self.__price_per_day * self.__rental_days


rental = CarRental("Toyota Camry", 50, 2)
rental.set_rental_days(5)

print(f"Car Name: {rental.get_car_name()}")
print(f"Price Per Day: ${rental.get_price_per_day()}")
print(f"Rental Days: {rental.get_rental_days()}")
print(f"Total Rental Cost: ${rental.calculate_total_cost()}")
# Out:
# Car Name: Toyota Camry
# Price Per Day: $50
# Rental Days: 5
# Total Rental Cost: $250
